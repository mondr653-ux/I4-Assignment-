# %% [markdown]
# <a href="https://colab.research.google.com/github/mondr653-ux/I4-Assignment-/blob/main/SQL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def access_json_via_api():
    """
    Accesses a public mock API to retrieve user data in JSON format.

    PROS of this methodology:
    - Highly structured and instantly parsable into native language dictionaries.
    - Designed for machine-to-machine communication; usually includes metadata (status codes).
    - Lightweight payload compared to XML or HTML.

    CONS of this methodology:
    - Subject to network latency, rate limits, and endpoint deprecation.
    - Security protocols (OAuth, API keys) can add overhead to the connection setup.
    """
    print("--- 1. JSON via REST API ---")
    url = "https://jsonplaceholder.typicode.com/users"

    try:
        response = requests.get(url)
        response.raise_for_status() # Check for HTTP errors

        # Parse the JSON structure
        data = response.json()

        # Print a sample (first user)
        print(f"Successfully retrieved {len(data)} records.")
        print("Sample Record:")
        print(f"Name: {data[0]['name']}")
        print(f"Email: {data[0]['email']}")
        print(f"Company: {data[0]['company']['name']}\n")

    except requests.exceptions.RequestException as e:
        print(f"API Connection Error: {e}")
